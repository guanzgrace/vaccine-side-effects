# %%
import numpy as np
import pandas as pd
from linearmodels.panel import PanelOLS, PooledOLS, RandomEffects
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import pickle as pkl
from pandas.plotting import autocorrelation_plot

# %% [markdown]
# # Load Datasets

# %%
df_hr_2 = pd.read_csv('panel_regr_data_hr_2.csv')
df_hrv_2 = pd.read_csv('panel_regr_data_hrv_2.csv')
df_hr_3 = pd.read_csv('panel_regr_data_hr_3.csv')
df_hrv_3 = pd.read_csv('panel_regr_data_hrv_3.csv')

# %%
with open('v2_participant_nums.pkl', 'rb') as f:
    v2_participant_nums = pkl.load(f)
    
with open('v3_participant_nums.pkl', 'rb') as f:
    v3_participant_nums = pkl.load(f)
    
    
    reaction_strength = {
    'No Reaction': v3_participant_nums[2],
    'Mild Reaction': v3_participant_nums[1],
    'Severe Reaction': v3_participant_nums[0],
}

# %% [markdown]
# # ACF Plot on 3rd Vaccine (Everyone)

# %%
def plot_acfs(df, label, text_label):
    parts = list(set(df['participant_num'].values))

    acfs = np.zeros((len(parts), 336))
    diffs = np.zeros((len(parts), 335))
    pacfs = np.zeros((len(parts), 26))
    
    for i in range(len(parts)):
        part = parts[i]
        s = df[df['participant_num']==part][label]
        acfs[i] = sm.tsa.acf(s, nlags = 336)
        pacfs[i] = sm.tsa.pacf(s)
        s = s.diff().iloc[1:] #First order difference to de-trend
        diffs[i] = sm.tsa.acf(s, nlags = 335)
        
    acf = np.nanmean(acfs, axis=0)
    pacf = np.nanmean(pacfs, axis=0)
    diff = np.nanmean(diffs, axis=0)
    
    # Plot autocorrelation plot
    plt.figure(figsize=(6,4))
    plt.axhline(2.57/np.sqrt(336), color='gray', linestyle='dashed', label='99% CI')
    plt.axhline(-2.57/np.sqrt(336), color='gray', linestyle='dashed')
    plt.plot(np.arange(1, 336), acf[1:], color='blue', label='Autocorrelation')
    plt.xticks(np.arange(0, 337, 24))
    plt.yticks(np.arange(-1, 1.1, 0.25))
    plt.xlabel("Lag (hours)")
    plt.ylabel("Autocorrelation")
    plt.title("Hourly %s after 3rd Vaccination" % (text_label))
    plt.legend()
    plt.show()
    
    # Plot diffed autocorrelation plot
    plt.figure(figsize=(6,4))
    plt.axhline(2.57/np.sqrt(336), color='gray', linestyle='dashed', label='99% CI')
    plt.axhline(-2.57/np.sqrt(336), color='gray', linestyle='dashed')
    plt.plot(np.arange(1, 335), diff[1:], color='blue', label='Autocorrelation')
    plt.xticks(np.arange(0, 337, 24))
    plt.yticks(np.arange(-1, 1.1, 0.25))
    plt.xlabel("Lag (hours)")
    plt.ylabel("Autocorrelation")
    plt.title("Diffed Hourly %s after 3rd Vaccination" % (text_label))
    plt.legend()
    plt.show()
    
    # Plot partial autocorrelation plot
    plt.figure(figsize=(6,4))
    plt.axhline(2.57/np.sqrt(336), color='gray', linestyle='dashed', label='99% CI')
    plt.axhline(-2.57/np.sqrt(336), color='gray', linestyle='dashed')
    plt.plot(np.arange(1, 26), pacf[1:], color='red', label='Partial Autocorrelation')
    plt.yticks(np.arange(-1, 1.1, 0.25))
    plt.xlabel("Lag (hours)")
    plt.ylabel("Partial Autocorrelation")
    plt.title("Hourly %s after 3rd Vaccination" % (text_label))
    plt.legend()
    plt.show()

# %%
plot_acfs(df_hr_3, 'hr', 'Heart Rate')

# %%
plot_acfs(df_hrv_3, 'hrv', 'Stress Measure')

# %%
# Plot a sample of 10 participants' autocorrelation
'''plt.figure(figsize=(8,5))

# Loop through participants and plot autocorrelation function

i = 0
for part in df['participant_num'].unique():
    s = df[df['participant_num']==part]['hr']
    s = s.diff().iloc[1:] #First order difference to de-trend
    ax = autocorrelation_plot(s)
    i += 1
    if i > 10:
        break
plt.title("Autocorrelation for Diffed Hourly HR after 3rd Vaccination (10 Samples)")
plt.xticks(np.arange(0, 337, 24))
plt.show()'''
# Out:
# 'plt.figure(figsize=(8,5))\n\n# Loop through participants and plot autocorrelation function\n\ni = 0\nfor part in df[\'participant_num\'].unique():\n    s = df[df[\'participant_num\']==part][\'hr\']\n    s = s.diff().iloc[1:] #First order difference to de-trend\n    ax = autocorrelation_plot(s)\n    i += 1\n    if i > 10:\n        break\nplt.title("Autocorrelation for Diffed Hourly HR after 3rd Vaccination (10 Samples)")\nplt.xticks(np.arange(0, 337, 24))\nplt.show()'

# %% [markdown]
# # Run Panel Regression on DF

# %%
def panel_regression(df, dep_var):
    dep_var
    
    
    df['gender'] = pd.Categorical(df['gender'])
    df['healthy'] = pd.Categorical(df['healthy'])
    df['vaccine_day'] = pd.Categorical(df['vaccine_day'])
    df['vaccine_hour'] = pd.Categorical(df['vaccine_hour'])

    participant_num = df.participant_num
    time = df.time

    df['%s_residual' % (dep_var)] = 0
    
    df['%s_offset_1' % (dep_var)] = df.groupby(['participant_num'])[dep_var].shift(1).fillna(0)
    
    df = df.set_index(['participant_num', 'time'])
    df['participant_num'] = pd.Categorical(participant_num)
    df['time'] = pd.Categorical(time)

    ##############################################################################

    X = df[['age', 'gender', 'healthy']]
    Y = df[dep_var]

    first_model = smf.ols(formula="%s ~ age + C(gender) + C(healthy) - 1" % (dep_var), data=df).fit()

    preds = Y - first_model.predict(X)

    df.loc[preds.index, '%s_residual' % (dep_var)] = preds
    
    print(first_model.summary())
    
    ##############################################################################
    
    fixed_effects_model = PanelOLS.from_formula("%s_residual ~ %s_offset_1 + after_vaccination + EntityEffects" % (dep_var, dep_var), data=df)
    print(fixed_effects_model.fit())
    
    ##############################################################################
    
    exog_vars = ['%s_offset_1' % (dep_var), 'after_vaccination']
    exog = sm.add_constant(df[exog_vars])
    random_effects_model = RandomEffects(df['%s_residual' % (dep_var)],  exog)
    re_res = random_effects_model.fit()
    
    print(re_res.variance_decomposition)
    print(print(re_res))
    #re_res.theta.head()

    return first_model, fixed_effects_model, random_effects_model

# %%
df_hr_3[df_hr_3.isna().any(axis=1)]
# Out:
#         Unnamed: 0  participant_num gender   age healthy      third_dose_date  \
# 336            336               10   Male  53.0    True  2021-08-25 12:45:00
# 337            337               10   Male  53.0    True  2021-08-25 12:45:00
# 338            338               10   Male  53.0    True  2021-08-25 12:45:00
# 352            352               10   Male  53.0    True  2021-08-25 12:45:00
# 353            353               10   Male  53.0    True  2021-08-25 12:45:00
# ...            ...              ...    ...   ...     ...                  ...
# 376280      376280               95   Male  54.0    True  2021-08-30 12:25:00
# 376281      376281               95   Male  54.0    True  2021-08-30 12:25:00
# 376282      376282               95   Male  54.0    True  2021-08-30 12:25:00
# 376283      376283               95   Male  54.0    True  2021-08-30 12:25:00
# 376284      376284               95   Male  54.0    True  2021-08-30 12:25:00
#
#        vaccine_day vaccine_hour  time  hr  after_vaccination  hr_residual  \
# 336              2           12  -168 NaN              False            0
# 337              2           13  -167 NaN              False            0
# 338              2           14  -166 NaN              False            0
# 352              2            4  -152 NaN              False            0
# 353              2            5  -151 NaN              False            0
# ...            ...          ...   ...  ..                ...          ...
# 376280           5           20   128 NaN              False            0
# 376281           5           21   129 NaN              False            0
# 376282           5           22   130 NaN              False            0
# 376283           5           23   131 NaN              False            0
# 376284           5            0   132 NaN              False            0
#
#         hr_offset_1
# 336        0.000000
# 337        0.000000
# 338        0.000000
# 352       74.794256
# 353        0.000000
# ...             ...
# 376280     0.000000
# 376281     0.000000
# 376282     0.000000
# 376283     0.000000
# 376284     0.000000
#
# [87414 rows x 13 columns]

# %%
# 3rd vaccine - everyone - hr

df = df_hr_3
df['after_vaccination'] = (df['time'] >= 0) & (df['time'] <= 24*3)
print(len(set(df_hr_3['participant_num'].values)))
panel_regression(df, 'hr')
# Out:
# 1121
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     hr   R-squared:                       0.036
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     3551.
# Date:                Wed, 11 May 2022   Prob (F-statistic):               0.00
# Time:                        04:38:49   Log-Likelihood:            -1.1749e+06
# No. Observations:              289242   AIC:                         2.350e+06
# Df Residuals:                  289238   BIC:                         2.350e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# C(gender)[Female]     85.3896      0.118    722.302      0.000      85.158      85.621
# C(gender)[Male]       82.1494      0.114    722.134      0.000      81.926      82.372
# C(healthy)[T.True]    -1.4746      0.056    -26.471      0.000      -1.584      -1.365
# age                   -0.1651      0.002    -88.828      0.000      -0.169      -0.162
# ==============================================================================
# Omnibus:                    11821.875   Durbin-Watson:                   0.354
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14227.513
# Skew:                           0.465   Prob(JB):                         0.00
# Kurtosis:                       3.561   Cond. No.                         334.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            hr_residual   R-squared:                        0.3482
# Estimator:                   PanelOLS   R-squared (Between):             -18.737
# No. Observations:              289242   R-squared (Within):               0.3482
# Date:                Wed, May 11 2022   R-squared (Overall):             -5.9630
# Time:                        04:38:50   Log-likelihood                -1.059e+06
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                   7.696e+04
# Entities:                        1070   P-value                           0.0000
# Avg Obs:                       270.32   Distribution:                F(2,288170)
# Min Obs:                       6.0000
# Max Obs:                       336.00   F-statistic (robust):          7.696e+04
#                                         P-value                           0.0000
# Time periods:                     336   Distribution:                F(2,288170)
# Avg Obs:                       860.84
# Min Obs:                       813.00
# Max Obs:                       909.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# after_vaccination     0.7422     0.0426     17.432     0.0000      0.6588      0.8257
# hr_offset_1           0.4818     0.0012     390.12     0.0000      0.4794      0.4842
# =====================================================================================
#
# F-test for Poolability: 50.067
# P-value: 0.0000
# Distribution: F(1069,288170)
#
# Included effects: Entity
# /opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:2575: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# Effects                    8.154184
# Residual                  89.165215
# Percent due to Effects     0.083788
# Name: Variance Decomposition, dtype: float64
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:            hr_residual   R-squared:                        0.3539
# Estimator:              RandomEffects   R-squared (Between):              0.6718
# No. Observations:              289242   R-squared (Within):               0.3481
# Date:                Wed, May 11 2022   R-squared (Overall):              0.4535
# Time:                        04:38:51   Log-likelihood                -1.061e+06
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                   7.922e+04
# Entities:                        1070   P-value                           0.0000
# Avg Obs:                       270.32   Distribution:                F(2,289239)
# Min Obs:                       6.0000
# Max Obs:                       336.00   F-statistic (robust):          7.921e+04
#                                         P-value                           0.0000
# Time periods:                     336   Distribution:                F(2,289239)
# Avg Obs:                       860.84
# Min Obs:                       813.00
# Max Obs:                       909.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# const                -35.808     0.1276    -280.69     0.0000     -36.058     -35.558
# hr_offset_1           0.4872     0.0012     395.89     0.0000      0.4847      0.4896
# after_vaccination     0.7232     0.0427     16.955     0.0000      0.6396      0.8069
# =====================================================================================
# None
# (<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7fc7ffa8e4f0>,
#  PanelOLS
#  Num exog: 2, Constant: False
#  Entity Effects: True, Time Effects: False, Num Other Effects: 0
#  id: 0x7fc7ffa7d7f0,
#  RandomEffects
#  Num exog: 3, Constant: True
#  id: 0x7fc7ffa7dd60)

# %%
# 3rd vaccine - everyone - hrv

df = df_hrv_3
df['after_vaccination'] = (df['time'] >= 0) & (df['time'] <= 24*3)

panel_regression(df, 'hrv')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    hrv   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     1695.
# Date:                Wed, 20 Apr 2022   Prob (F-statistic):               0.00
# Time:                        01:08:43   Log-Likelihood:            -1.2794e+06
# No. Observations:              285238   AIC:                         2.559e+06
# Df Residuals:                  285234   BIC:                         2.559e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# C(gender)[Female]     40.9776      0.181    225.955      0.000      40.622      41.333
# C(gender)[Male]       42.1160      0.174    241.364      0.000      41.774      42.458
# C(healthy)[T.True]     0.9068      0.086     10.582      0.000       0.739       1.075
# age                   -0.1748      0.003    -61.379      0.000      -0.180      -0.169
# ==============================================================================
# Omnibus:                    19538.922   Durbin-Watson:                   0.425
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            20054.071
# Skew:                           0.606   Prob(JB):                         0.00
# Kurtosis:                       2.531   Cond. No.                         333.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:           hrv_residual   R-squared:                        0.5595
# Estimator:                   PanelOLS   R-squared (Between):             -9.8890
# No. Observations:              285238   R-squared (Within):               0.5595
# Date:                Wed, Apr 20 2022   R-squared (Overall):             -0.6892
# Time:                        01:08:44   Log-likelihood                -1.148e+06
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                   1.805e+05
# Entities:                        1063   P-value                           0.0000
# Avg Obs:                       268.33   Distribution:                F(2,284173)
# Min Obs:                       6.0000
# Max Obs:                       336.00   F-statistic (robust):          1.805e+05
#                                         P-value                           0.0000
# Time periods:                     336   Distribution:                F(2,284173)
# Avg Obs:                       848.92
# Min Obs:                       800.00
# Max Obs:                       899.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# after_vaccination     0.9139     0.0616     14.826     0.0000      0.7931      1.0347
# hrv_offset_1          0.7377     0.0012     597.18     0.0000      0.7353      0.7401
# =====================================================================================
#
# F-test for Poolability: 11.203
# P-value: 0.0000
# Distribution: F(1062,284173)
#
# Included effects: Entity
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   x = pd.concat(x[::order], 1)
# /opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:2575: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# Effects                     6.743405
# Residual                  183.483990
# Percent due to Effects      0.035449
# Name: Variance Decomposition, dtype: float64
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:           hrv_residual   R-squared:                        0.5623
# Estimator:              RandomEffects   R-squared (Between):              0.8315
# No. Observations:              285238   R-squared (Within):               0.5595
# Date:                Wed, Apr 20 2022   R-squared (Overall):              0.5865
# Time:                        01:08:44   Log-likelihood                -1.148e+06
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                   1.832e+05
# Entities:                        1063   P-value                           0.0000
# Avg Obs:                       268.33   Distribution:                F(2,285235)
# Min Obs:                       6.0000
# Max Obs:                       336.00   F-statistic (robust):          1.832e+05
#                                         P-value                           0.0000
# Time periods:                     336   Distribution:                F(2,285235)
# Avg Obs:                       848.92
# Min Obs:                       800.00
# Max Obs:                       899.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# const                -24.351     0.0941    -258.89     0.0000     -24.535     -24.167
# hrv_offset_1          0.7392     0.0012     601.85     0.0000      0.7368      0.7416
# after_vaccination     0.8997     0.0615     14.618     0.0000      0.7791      1.0204
# =====================================================================================
# None
# (<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f4214d884f0>,
#  PanelOLS
#  Num exog: 2, Constant: False
#  Entity Effects: True, Time Effects: False, Num Other Effects: 0
#  id: 0x7f4214c2f610,
#  RandomEffects
#  Num exog: 3, Constant: True
#  id: 0x7f4214c39d00)

# %%
# 3rd vaccine - asymptomatic - hr

df = df_hr_3
df['participant_num'] = df['participant_num'].astype(str)
df = df[df['participant_num'].isin(v3_participant_nums[2])]
df['after_vaccination'] = (df['time'] >= 0) & (df['time'] <= 24*3)

panel_regression(df, 'hr')
# Out:
# <ipython-input-15-56afa495bd4e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['after_vaccination'] = (df['time'] >= 0) & (df['time'] <= 24*3)
# <ipython-input-12-5bfe7c118de3>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gender'] = pd.Categorical(df['gender'])
# <ipython-input-12-5bfe7c118de3>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['vaccine_day'] = pd.Categorical(df['vaccine_day'])
# <ipython-input-12-5bfe7c118de3>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['vaccine_hour'] = pd.Categorical(df['vaccine_hour'])
# <ipython-input-12-5bfe7c118de3>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['%s_residual' % (dep_var)] = 0
# <ipython-input-12-5bfe7c118de3>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['%s_offset_1' % (dep_var)] = df.groupby(['participant_num'])[dep_var].shift(1).fillna(0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     hr   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                     1402.
# Date:                Wed, 20 Apr 2022   Prob (F-statistic):               0.00
# Time:                        01:08:47   Log-Likelihood:            -5.7411e+05
# No. Observations:              141869   AIC:                         1.148e+06
# Df Residuals:                  141865   BIC:                         1.148e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# C(gender)[Female]     85.0400      0.185    460.091      0.000      84.678      85.402
# C(gender)[Male]       82.2678      0.171    481.028      0.000      81.933      82.603
# C(healthy)[T.True]    -1.6324      0.078    -20.985      0.000      -1.785      -1.480
# age                   -0.1638      0.003    -58.868      0.000      -0.169      -0.158
# ==============================================================================
# Omnibus:                     8658.832   Durbin-Watson:                   0.365
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11746.782
# Skew:                           0.558   Prob(JB):                         0.00
# Kurtosis:                       3.860   Cond. No.                         382.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            hr_residual   R-squared:                        0.3399
# Estimator:                   PanelOLS   R-squared (Between):             -18.321
# No. Observations:              141869   R-squared (Within):               0.3399
# Date:                Wed, Apr 20 2022   R-squared (Overall):             -5.8062
# Time:                        01:08:48   Log-likelihood                -5.186e+05
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                    3.64e+04
# Entities:                         523   P-value                           0.0000
# Avg Obs:                       271.26   Distribution:                F(2,141344)
# Min Obs:                       6.0000
# Max Obs:                       336.00   F-statistic (robust):           3.64e+04
#                                         P-value                           0.0000
# Time periods:                     336   Distribution:                F(2,141344)
# Avg Obs:                       422.23
# Min Obs:                       392.00
# Max Obs:                       448.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# after_vaccination     0.5109     0.0606     8.4370     0.0000      0.3922      0.6296
# hr_offset_1           0.4740     0.0018     268.96     0.0000      0.4705      0.4774
# =====================================================================================
#
# F-test for Poolability: 49.568
# P-value: 0.0000
# Distribution: F(522,141344)
#
# Included effects: Entity
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   x = pd.concat(x[::order], 1)
# /opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:2575: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# Effects                    6.981306
# Residual                  87.985251
# Percent due to Effects     0.073513
# Name: Variance Decomposition, dtype: float64
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:            hr_residual   R-squared:                        0.3464
# Estimator:              RandomEffects   R-squared (Between):              0.6635
# No. Observations:              141869   R-squared (Within):               0.3399
# Date:                Wed, Apr 20 2022   R-squared (Overall):              0.4449
# Time:                        01:08:49   Log-likelihood                -5.193e+05
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                    3.76e+04
# Entities:                         523   P-value                           0.0000
# Avg Obs:                       271.26   Distribution:                F(2,141866)
# Min Obs:                       6.0000
# Max Obs:                       336.00   F-statistic (robust):          3.759e+04
#                                         P-value                           0.0000
# Time periods:                     336   Distribution:                F(2,141866)
# Avg Obs:                       422.23
# Min Obs:                       392.00
# Max Obs:                       448.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# const                -34.854     0.1752    -198.93     0.0000     -35.197     -34.510
# hr_offset_1           0.4802     0.0018     273.39     0.0000      0.4767      0.4836
# after_vaccination     0.4922     0.0607     8.1084     0.0000      0.3732      0.6111
# =====================================================================================
# None
# (<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f4214ca89a0>,
#  PanelOLS
#  Num exog: 2, Constant: False
#  Entity Effects: True, Time Effects: False, Num Other Effects: 0
#  id: 0x7f4214c2f0d0,
#  RandomEffects
#  Num exog: 3, Constant: True
#  id: 0x7f4214cb8d60)

# %%
# 3rd vaccine - asymptomatic - hrv

df = df_hrv_3
df['participant_num'] = df['participant_num'].astype(str)
df = df[df['participant_num'].isin(v3_participant_nums[2])]
df['after_vaccination'] = (df['time'] >= 0) & (df['time'] <= 24*3)

panel_regression(df, 'hrv')
# Out:
# <ipython-input-16-f6ca50fdc496>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['after_vaccination'] = (df['time'] >= 0) & (df['time'] <= 24*3)
# <ipython-input-12-5bfe7c118de3>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gender'] = pd.Categorical(df['gender'])
# <ipython-input-12-5bfe7c118de3>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['vaccine_day'] = pd.Categorical(df['vaccine_day'])
# <ipython-input-12-5bfe7c118de3>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['vaccine_hour'] = pd.Categorical(df['vaccine_hour'])
# <ipython-input-12-5bfe7c118de3>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['%s_residual' % (dep_var)] = 0
# <ipython-input-12-5bfe7c118de3>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['%s_offset_1' % (dep_var)] = df.groupby(['participant_num'])[dep_var].shift(1).fillna(0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    hrv   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     898.8
# Date:                Wed, 20 Apr 2022   Prob (F-statistic):               0.00
# Time:                        01:08:51   Log-Likelihood:            -6.2242e+05
# No. Observations:              139225   AIC:                         1.245e+06
# Df Residuals:                  139221   BIC:                         1.245e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# C(gender)[Female]     40.5755      0.284    142.975      0.000      40.019      41.132
# C(gender)[Male]       41.6879      0.262    158.880      0.000      41.174      42.202
# C(healthy)[T.True]     1.7162      0.120     14.309      0.000       1.481       1.951
# age                   -0.1719      0.004    -40.314      0.000      -0.180      -0.164
# ==============================================================================
# Omnibus:                     9352.398   Durbin-Watson:                   0.429
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10251.058
# Skew:                           0.634   Prob(JB):                         0.00
# Kurtosis:                       2.603   Cond. No.                         380.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:           hrv_residual   R-squared:                        0.5550
# Estimator:                   PanelOLS   R-squared (Between):             -8.7928
# No. Observations:              139225   R-squared (Within):               0.5550
# Date:                Wed, Apr 20 2022   R-squared (Overall):             -0.6924
# Time:                        01:08:52   Log-likelihood                -5.585e+05
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                   8.649e+04
# Entities:                         519   P-value                           0.0000
# Avg Obs:                       268.26   Distribution:                F(2,138704)
# Min Obs:                       6.0000
# Max Obs:                       336.00   F-statistic (robust):          8.649e+04
#                                         P-value                           0.0000
# Time periods:                     336   Distribution:                F(2,138704)
# Avg Obs:                       414.36
# Min Obs:                       385.00
# Max Obs:                       441.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# after_vaccination     0.6291     0.0875     7.1940     0.0000      0.4577      0.8005
# hrv_offset_1          0.7350     0.0018     414.53     0.0000      0.7316      0.7385
# =====================================================================================
#
# F-test for Poolability: 12.037
# P-value: 0.0000
# Distribution: F(518,138704)
#
# Included effects: Entity
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   x = pd.concat(x[::order], 1)
# /opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:2575: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# Effects                     7.775976
# Residual                  179.232018
# Percent due to Effects      0.041581
# Name: Variance Decomposition, dtype: float64
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:           hrv_residual   R-squared:                        0.5575
# Estimator:              RandomEffects   R-squared (Between):              0.8198
# No. Observations:              139225   R-squared (Within):               0.5550
# Date:                Wed, Apr 20 2022   R-squared (Overall):              0.5827
# Time:                        01:08:53   Log-likelihood                -5.588e+05
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                   8.771e+04
# Entities:                         519   P-value                           0.0000
# Avg Obs:                       268.26   Distribution:                F(2,139222)
# Min Obs:                       6.0000
# Max Obs:                       336.00   F-statistic (robust):          8.771e+04
#                                         P-value                           0.0000
# Time periods:                     336   Distribution:                F(2,139222)
# Avg Obs:                       414.36
# Min Obs:                       385.00
# Max Obs:                       441.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# const                -23.967     0.1419    -168.88     0.0000     -24.245     -23.689
# hrv_offset_1          0.7364     0.0018     417.45     0.0000      0.7330      0.7399
# after_vaccination     0.6225     0.0873     7.1279     0.0000      0.4513      0.7937
# =====================================================================================
# None
# (<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f4214c595b0>,
#  PanelOLS
#  Num exog: 2, Constant: False
#  Entity Effects: True, Time Effects: False, Num Other Effects: 0
#  id: 0x7f4214c2f460,
#  RandomEffects
#  Num exog: 3, Constant: True
#  id: 0x7f4214c2f820)

# %%
# 2nd vaccine - everyone - hr

df = df_hr_2
df['after_vaccination'] = (df['time'] >= 0) & (df['time'] <= 24*3)

panel_regression(df, 'hr')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     hr   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     319.1
# Date:                Wed, 20 Apr 2022   Prob (F-statistic):          4.02e-205
# Time:                        01:08:53   Log-Likelihood:            -1.8755e+05
# No. Observations:               46850   AIC:                         3.751e+05
# Df Residuals:                   46846   BIC:                         3.751e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# C(gender)[Female]     76.5057      0.417    183.643      0.000      75.689      77.322
# C(gender)[Male]       72.7634      0.410    177.470      0.000      71.960      73.567
# C(healthy)[T.True]    -0.8243      0.136     -6.080      0.000      -1.090      -0.559
# age                   -0.0238      0.006     -3.733      0.000      -0.036      -0.011
# ==============================================================================
# Omnibus:                     9998.598   Durbin-Watson:                   0.413
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            36597.154
# Skew:                           1.043   Prob(JB):                         0.00
# Kurtosis:                       6.794   Cond. No.                         554.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            hr_residual   R-squared:                        0.3129
# Estimator:                   PanelOLS   R-squared (Between):             -17.566
# No. Observations:               46850   R-squared (Within):               0.3129
# Date:                Wed, Apr 20 2022   R-squared (Overall):             -5.7298
# Time:                        01:08:53   Log-likelihood                -1.705e+05
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                   1.063e+04
# Entities:                         163   P-value                           0.0000
# Avg Obs:                       287.42   Distribution:                 F(2,46685)
# Min Obs:                       6.0000
# Max Obs:                       336.00   F-statistic (robust):          1.063e+04
#                                         P-value                           0.0000
# Time periods:                     336   Distribution:                 F(2,46685)
# Avg Obs:                       139.43
# Min Obs:                       130.00
# Max Obs:                       148.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# after_vaccination     0.7648     0.1041     7.3443     0.0000      0.5607      0.9689
# hr_offset_1           0.4552     0.0031     144.96     0.0000      0.4491      0.4614
# =====================================================================================
#
# F-test for Poolability: 50.849
# P-value: 0.0000
# Distribution: F(162,46685)
#
# Included effects: Entity
# /opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   x = pd.concat(x[::order], 1)
# /opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:2575: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# Effects                    5.568070
# Residual                  85.047752
# Percent due to Effects     0.061447
# Name: Variance Decomposition, dtype: float64
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:            hr_residual   R-squared:                        0.3204
# Estimator:              RandomEffects   R-squared (Between):              0.6413
# No. Observations:               46850   R-squared (Within):               0.3128
# Date:                Wed, Apr 20 2022   R-squared (Overall):              0.4172
# Time:                        01:08:54   Log-likelihood                -1.708e+05
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                   1.104e+04
# Entities:                         163   P-value                           0.0000
# Avg Obs:                       287.42   Distribution:                 F(2,46847)
# Min Obs:                       6.0000
# Max Obs:                       336.00   F-statistic (robust):          1.104e+04
#                                         P-value                           0.0000
# Time periods:                     336   Distribution:                 F(2,46847)
# Avg Obs:                       139.43
# Min Obs:                       130.00
# Max Obs:                       148.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# const                -32.986     0.2963    -111.34     0.0000     -33.567     -32.406
# hr_offset_1           0.4627     0.0031     147.80     0.0000      0.4566      0.4688
# after_vaccination     0.7331     0.1045     7.0142     0.0000      0.5283      0.9380
# =====================================================================================
# None
# (<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f4214ca8b80>,
#  PanelOLS
#  Num exog: 2, Constant: False
#  Entity Effects: True, Time Effects: False, Num Other Effects: 0
#  id: 0x7f4214e7e550,
#  RandomEffects
#  Num exog: 3, Constant: True
#  id: 0x7f4214cdcdc0)

# %%
# 2nd vaccine - everyone - hrv

df = df_hrv_2
df['after_vaccination'] = (df['time'] >= 0) & (df['time'] <= 24*3)

panel_regression(df, 'hrv')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    hrv   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     29.48
# Date:                Wed, 20 Apr 2022   Prob (F-statistic):           4.94e-19
# Time:                        01:08:54   Log-Likelihood:            -1.8979e+05
# No. Observations:               43411   AIC:                         3.796e+05
# Df Residuals:                   43407   BIC:                         3.796e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# C(gender)[Female]     27.9074      0.618     45.147      0.000      26.696      29.119
# C(gender)[Male]       27.9504      0.612     45.665      0.000      26.751      29.150
# C(healthy)[T.True]     1.8900      0.206      9.176      0.000       1.486       2.294
# age                    0.0105      0.009      1.111      0.266      -0.008       0.029
# ==============================================================================
# Omnibus:                     3785.794   Durbin-Watson:                   0.473
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4880.021
# Skew:                           0.821   Prob(JB):                         0.00
# Kurtosis:                       3.057   Cond. No.                         551.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:           hrv_residual   R-squared:                        0.5205
# Estimator:                   PanelOLS   R-squared (Between):             -8.4718
# No. Observations:               43411   R-squared (Within):               0.5205
# Date:                Wed, Apr 20 2022   R-squared (Overall):             -0.6563
# Time:                        01:08:54   Log-likelihood                -1.714e+05
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                   2.348e+04
# Entities:                         151   P-value                           0.0000
# Avg Obs:                       287.49   Distribution:                 F(2,43258)
# Min Obs:                       6.0000
# Max Obs:                       336.00   F-statistic (robust):          2.348e+04
#                                         P-value                           0.0000
# Time periods:                     336   Distribution:                 F(2,43258)
# Avg Obs:                       129.20
# Min Obs:                       119.00
# Max Obs:                       138.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# after_vaccination     0.7688     0.1475     5.2106     0.0000      0.4796      1.0579
# hrv_offset_1          0.7126     0.0033     215.71     0.0000      0.7061      0.7190
# =====================================================================================
#
# F-test for Poolability: 6.6545
# P-value: 0.0000
# Distribution: F(150,43258)
#
# Included effects: Entity
# /opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   x = pd.concat(x[::order], 1)
# /opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:2575: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# Effects                     0.467169
# Residual                  158.183968
# Percent due to Effects      0.002945
# Name: Variance Decomposition, dtype: float64
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:           hrv_residual   R-squared:                        0.5430
# Estimator:              RandomEffects   R-squared (Between):              0.8849
# No. Observations:               43411   R-squared (Within):               0.5202
# Date:                Wed, Apr 20 2022   R-squared (Overall):              0.5607
# Time:                        01:08:55   Log-likelihood                -1.717e+05
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                   2.579e+04
# Entities:                         151   P-value                           0.0000
# Avg Obs:                       287.49   Distribution:                 F(2,43408)
# Min Obs:                       6.0000
# Max Obs:                       336.00   F-statistic (robust):          2.579e+04
#                                         P-value                           0.0000
# Time periods:                     336   Distribution:                 F(2,43408)
# Avg Obs:                       129.20
# Min Obs:                       119.00
# Max Obs:                       138.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# const                -21.576     0.1286    -167.74     0.0000     -21.828     -21.324
# hrv_offset_1          0.7289     0.0032     226.21     0.0000      0.7225      0.7352
# after_vaccination     0.6895     0.1478     4.6652     0.0000      0.3998      0.9791
# =====================================================================================
# None
# (<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f4214cca640>,
#  PanelOLS
#  Num exog: 2, Constant: False
#  Entity Effects: True, Time Effects: False, Num Other Effects: 0
#  id: 0x7f4214da0a60,
#  RandomEffects
#  Num exog: 3, Constant: True
#  id: 0x7f4214da07c0)

# %%
# 2nd vaccine - asymptomatic - hr

df = df_hr_2
df['participant_num'] = df['participant_num'].astype(str)
df = df[df['participant_num'].isin(v2_participant_nums[2])]
df['after_vaccination'] = (df['time'] >= 0) & (df['time'] <= 24*3)

panel_regression(df, 'hr')
# Out:
# <ipython-input-19-084bb1e1bde7>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['after_vaccination'] = (df['time'] >= 0) & (df['time'] <= 24*3)
# <ipython-input-12-5bfe7c118de3>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gender'] = pd.Categorical(df['gender'])
# <ipython-input-12-5bfe7c118de3>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['vaccine_day'] = pd.Categorical(df['vaccine_day'])
# <ipython-input-12-5bfe7c118de3>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['vaccine_hour'] = pd.Categorical(df['vaccine_hour'])
# <ipython-input-12-5bfe7c118de3>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['%s_residual' % (dep_var)] = 0
# <ipython-input-12-5bfe7c118de3>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['%s_offset_1' % (dep_var)] = df.groupby(['participant_num'])[dep_var].shift(1).fillna(0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     hr   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     58.88
# Date:                Wed, 20 Apr 2022   Prob (F-statistic):           6.51e-38
# Time:                        01:08:55   Log-Likelihood:                -93930.
# No. Observations:               23475   AIC:                         1.879e+05
# Df Residuals:                   23471   BIC:                         1.879e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# C(gender)[Female]     69.8617      0.644    108.471      0.000      68.599      71.124
# C(gender)[Male]       68.3359      0.631    108.252      0.000      67.099      69.573
# C(healthy)[T.True]    -0.5433      0.188     -2.894      0.004      -0.911      -0.175
# age                    0.0779      0.010      7.987      0.000       0.059       0.097
# ==============================================================================
# Omnibus:                     4079.662   Durbin-Watson:                   0.379
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11317.056
# Skew:                           0.935   Prob(JB):                         0.00
# Kurtosis:                       5.842   Cond. No.                         625.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            hr_residual   R-squared:                        0.3234
# Estimator:                   PanelOLS   R-squared (Between):             -16.643
# No. Observations:               23475   R-squared (Within):               0.3234
# Date:                Wed, Apr 20 2022   R-squared (Overall):             -5.9993
# Time:                        01:08:55   Log-likelihood                -8.464e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      5591.7
# Entities:                          81   P-value                           0.0000
# Avg Obs:                       289.81   Distribution:                 F(2,23392)
# Min Obs:                       21.000
# Max Obs:                       336.00   F-statistic (robust):             5591.7
#                                         P-value                           0.0000
# Time periods:                     336   Distribution:                 F(2,23392)
# Avg Obs:                       69.866
# Min Obs:                       62.000
# Max Obs:                       75.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# after_vaccination     0.4506     0.1419     3.1755     0.0015      0.1725      0.7288
# hr_offset_1           0.4618     0.0044     105.43     0.0000      0.4533      0.4704
# =====================================================================================
#
# F-test for Poolability: 54.866
# P-value: 0.0000
# Distribution: F(80,23392)
#
# Included effects: Entity
# Effects                    2.826366
# Residual                  79.580830
# Percent due to Effects     0.034298
# Name: Variance Decomposition, dtype: float64
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:            hr_residual   R-squared:                        0.3388
# Estimator:              RandomEffects   R-squared (Between):              0.6726
# No. Observations:               23475   R-squared (Within):               0.3231
# Date:                Wed, Apr 20 2022   R-squared (Overall):              0.4440
# Time:                        01:08:55   Log-likelihood                 -8.49e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      6014.5
# Entities:                          81   P-value                           0.0000
# Avg Obs:                       289.81   Distribution:                 F(2,23472)
# Min Obs:                       21.000
# Max Obs:                       336.00   F-statistic (robust):             6011.1
#                                         P-value                           0.0000
# Time periods:                     336   Distribution:                 F(2,23472)
# Avg Obs:                       69.866
# Min Obs:                       62.000
# Max Obs:                       75.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# const                -34.281     0.3751    -91.384     0.0000     -35.016     -33.545
# hr_offset_1           0.4771     0.0044     109.36     0.0000      0.4686      0.4857
# after_vaccination     0.4007     0.1431     2.7996     0.0051      0.1201      0.6812
# =====================================================================================
# None
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   x = pd.concat(x[::order], 1)
# /opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:2575: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# (<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f426c055040>,
#  PanelOLS
#  Num exog: 2, Constant: False
#  Entity Effects: True, Time Effects: False, Num Other Effects: 0
#  id: 0x7f4214dbb460,
#  RandomEffects
#  Num exog: 3, Constant: True
#  id: 0x7f4214dbb100)

# %%
# 2nd vaccine - asymptomatic - hrv

df = df_hrv_2
df['participant_num'] = df['participant_num'].astype(str)
df = df[df['participant_num'].isin(v2_participant_nums[2])]
df['after_vaccination'] = (df['time'] >= 0) & (df['time'] <= 24*3)

panel_regression(df, 'hrv')
# Out:
# <ipython-input-20-98f4afd1cfc1>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['after_vaccination'] = (df['time'] >= 0) & (df['time'] <= 24*3)
# <ipython-input-12-5bfe7c118de3>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gender'] = pd.Categorical(df['gender'])
# <ipython-input-12-5bfe7c118de3>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['vaccine_day'] = pd.Categorical(df['vaccine_day'])
# <ipython-input-12-5bfe7c118de3>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['vaccine_hour'] = pd.Categorical(df['vaccine_hour'])
# <ipython-input-12-5bfe7c118de3>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['%s_residual' % (dep_var)] = 0
# <ipython-input-12-5bfe7c118de3>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['%s_offset_1' % (dep_var)] = df.groupby(['participant_num'])[dep_var].shift(1).fillna(0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    hrv   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     80.24
# Date:                Wed, 20 Apr 2022   Prob (F-statistic):           1.25e-51
# Time:                        01:08:56   Log-Likelihood:                -98352.
# No. Observations:               22490   AIC:                         1.967e+05
# Df Residuals:                   22486   BIC:                         1.967e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# C(gender)[Female]     15.7506      0.946     16.657      0.000      13.897      17.604
# C(gender)[Male]       17.7462      0.929     19.111      0.000      15.926      19.566
# C(healthy)[T.True]     2.5005      0.276      9.070      0.000       1.960       3.041
# age                    0.1840      0.014     12.834      0.000       0.156       0.212
# ==============================================================================
# Omnibus:                     1970.923   Durbin-Watson:                   0.474
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2542.357
# Skew:                           0.823   Prob(JB):                         0.00
# Kurtosis:                       3.055   Cond. No.                         621.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:           hrv_residual   R-squared:                        0.5191
# Estimator:                   PanelOLS   R-squared (Between):             -8.0056
# No. Observations:               22490   R-squared (Within):               0.5191
# Date:                Wed, Apr 20 2022   R-squared (Overall):             -0.6145
# Time:                        01:08:56   Log-likelihood                -8.882e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                    1.21e+04
# Entities:                          78   P-value                           0.0000
# Avg Obs:                       288.33   Distribution:                 F(2,22410)
# Min Obs:                       21.000
# Max Obs:                       336.00   F-statistic (robust):           1.21e+04
#                                         P-value                           0.0000
# Time periods:                     336   Distribution:                 F(2,22410)
# Avg Obs:                       66.935
# Min Obs:                       60.000
# Max Obs:                       72.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# after_vaccination     0.6024     0.2044     2.9466     0.0032      0.2017      1.0032
# hrv_offset_1          0.7124     0.0046     155.09     0.0000      0.7034      0.7215
# =====================================================================================
#
# F-test for Poolability: 10.221
# P-value: 0.0000
# Distribution: F(77,22410)
#
# Included effects: Entity
# /opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   x = pd.concat(x[::order], 1)
# /opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:2575: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# Effects                     3.654081
# Residual                  158.238428
# Percent due to Effects      0.022571
# Name: Variance Decomposition, dtype: float64
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:           hrv_residual   R-squared:                        0.5250
# Estimator:              RandomEffects   R-squared (Between):              0.8521
# No. Observations:               22490   R-squared (Within):               0.5191
# Date:                Wed, Apr 20 2022   R-squared (Overall):              0.5562
# Time:                        01:08:56   Log-likelihood                -8.888e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                   1.242e+04
# Entities:                          78   P-value                           0.0000
# Avg Obs:                       288.33   Distribution:                 F(2,22487)
# Min Obs:                       21.000
# Max Obs:                       336.00   F-statistic (robust):          1.242e+04
#                                         P-value                           0.0000
# Time periods:                     336   Distribution:                 F(2,22487)
# Avg Obs:                       66.935
# Min Obs:                       60.000
# Max Obs:                       72.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# const                -20.813     0.2716    -76.637     0.0000     -21.345     -20.281
# hrv_offset_1          0.7165     0.0046     157.19     0.0000      0.7076      0.7255
# after_vaccination     0.5793     0.2043     2.8346     0.0046      0.1787      0.9798
# =====================================================================================
# None
# (<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f4214e7e8b0>,
#  PanelOLS
#  Num exog: 2, Constant: False
#  Entity Effects: True, Time Effects: False, Num Other Effects: 0
#  id: 0x7f4214e305e0,
#  RandomEffects
#  Num exog: 3, Constant: True
#  id: 0x7f4214e44640)

# %%
# 3rd vaccine - asymptomatic - hr - don't include day of vaccination

df = df_hr_3
df['participant_num'] = df['participant_num'].astype(str)
df = df[df['participant_num'].isin(v3_participant_nums[2])]
df['after_vaccination'] = (df['time'] >= 24) & (df['time'] <= 24*3)

panel_regression(df, 'hr')
# Out:
# <ipython-input-21-25b3811b47ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['after_vaccination'] = (df['time'] >= 24) & (df['time'] <= 24*3)
# <ipython-input-12-5bfe7c118de3>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gender'] = pd.Categorical(df['gender'])
# <ipython-input-12-5bfe7c118de3>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['vaccine_day'] = pd.Categorical(df['vaccine_day'])
# <ipython-input-12-5bfe7c118de3>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['vaccine_hour'] = pd.Categorical(df['vaccine_hour'])
# <ipython-input-12-5bfe7c118de3>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['%s_residual' % (dep_var)] = 0
# <ipython-input-12-5bfe7c118de3>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['%s_offset_1' % (dep_var)] = df.groupby(['participant_num'])[dep_var].shift(1).fillna(0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     hr   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                     1402.
# Date:                Wed, 20 Apr 2022   Prob (F-statistic):               0.00
# Time:                        01:08:59   Log-Likelihood:            -5.7411e+05
# No. Observations:              141869   AIC:                         1.148e+06
# Df Residuals:                  141865   BIC:                         1.148e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# C(gender)[Female]     85.0400      0.185    460.091      0.000      84.678      85.402
# C(gender)[Male]       82.2678      0.171    481.028      0.000      81.933      82.603
# C(healthy)[T.True]    -1.6324      0.078    -20.985      0.000      -1.785      -1.480
# age                   -0.1638      0.003    -58.868      0.000      -0.169      -0.158
# ==============================================================================
# Omnibus:                     8658.832   Durbin-Watson:                   0.365
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11746.782
# Skew:                           0.558   Prob(JB):                         0.00
# Kurtosis:                       3.860   Cond. No.                         382.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            hr_residual   R-squared:                        0.3398
# Estimator:                   PanelOLS   R-squared (Between):             -18.293
# No. Observations:              141869   R-squared (Within):               0.3398
# Date:                Wed, Apr 20 2022   R-squared (Overall):             -5.7964
# Time:                        01:08:59   Log-likelihood                -5.186e+05
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                   3.637e+04
# Entities:                         523   P-value                           0.0000
# Avg Obs:                       271.26   Distribution:                F(2,141344)
# Min Obs:                       6.0000
# Max Obs:                       336.00   F-statistic (robust):          3.637e+04
#                                         P-value                           0.0000
# Time periods:                     336   Distribution:                F(2,141344)
# Avg Obs:                       422.23
# Min Obs:                       392.00
# Max Obs:                       448.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# after_vaccination     0.4027     0.0704     5.7202     0.0000      0.2647      0.5407
# hr_offset_1           0.4743     0.0018     269.27     0.0000      0.4709      0.4778
# =====================================================================================
#
# F-test for Poolability: 49.507
# P-value: 0.0000
# Distribution: F(522,141344)
#
# Included effects: Entity
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   x = pd.concat(x[::order], 1)
# /opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:2575: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# Effects                    6.914734
# Residual                  88.009188
# Percent due to Effects     0.072845
# Name: Variance Decomposition, dtype: float64
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:            hr_residual   R-squared:                        0.3463
# Estimator:              RandomEffects   R-squared (Between):              0.6640
# No. Observations:              141869   R-squared (Within):               0.3397
# Date:                Wed, Apr 20 2022   R-squared (Overall):              0.4449
# Time:                        01:09:00   Log-likelihood                -5.194e+05
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                   3.758e+04
# Entities:                         523   P-value                           0.0000
# Avg Obs:                       271.26   Distribution:                F(2,141866)
# Min Obs:                       6.0000
# Max Obs:                       336.00   F-statistic (robust):          3.758e+04
#                                         P-value                           0.0000
# Time periods:                     336   Distribution:                F(2,141866)
# Avg Obs:                       422.23
# Min Obs:                       392.00
# Max Obs:                       448.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# const                -34.832     0.1748    -199.26     0.0000     -35.175     -34.490
# hr_offset_1           0.4806     0.0018     273.73     0.0000      0.4771      0.4840
# after_vaccination     0.3830     0.0706     5.4271     0.0000      0.2447      0.5214
# =====================================================================================
# None
# (<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f4214d70070>,
#  PanelOLS
#  Num exog: 2, Constant: False
#  Entity Effects: True, Time Effects: False, Num Other Effects: 0
#  id: 0x7f4214fd5d30,
#  RandomEffects
#  Num exog: 3, Constant: True
#  id: 0x7f4214c66c10)

# %%
# 3rd vaccine - asymptomatic - hrv - don't include day of vaccination

df = df_hrv_3
df['participant_num'] = df['participant_num'].astype(str)
df = df[df['participant_num'].isin(v3_participant_nums[2])]
df['after_vaccination'] = (df['time'] >= 24) & (df['time'] <= 24*3)

panel_regression(df, 'hrv')
# Out:
# <ipython-input-22-8085dcea893f>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['after_vaccination'] = (df['time'] >= 24) & (df['time'] <= 24*3)
# <ipython-input-12-5bfe7c118de3>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gender'] = pd.Categorical(df['gender'])
# <ipython-input-12-5bfe7c118de3>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['vaccine_day'] = pd.Categorical(df['vaccine_day'])
# <ipython-input-12-5bfe7c118de3>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['vaccine_hour'] = pd.Categorical(df['vaccine_hour'])
# <ipython-input-12-5bfe7c118de3>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['%s_residual' % (dep_var)] = 0
# <ipython-input-12-5bfe7c118de3>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['%s_offset_1' % (dep_var)] = df.groupby(['participant_num'])[dep_var].shift(1).fillna(0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    hrv   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     898.8
# Date:                Wed, 20 Apr 2022   Prob (F-statistic):               0.00
# Time:                        01:09:02   Log-Likelihood:            -6.2242e+05
# No. Observations:              139225   AIC:                         1.245e+06
# Df Residuals:                  139221   BIC:                         1.245e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# C(gender)[Female]     40.5755      0.284    142.975      0.000      40.019      41.132
# C(gender)[Male]       41.6879      0.262    158.880      0.000      41.174      42.202
# C(healthy)[T.True]     1.7162      0.120     14.309      0.000       1.481       1.951
# age                   -0.1719      0.004    -40.314      0.000      -0.180      -0.164
# ==============================================================================
# Omnibus:                     9352.398   Durbin-Watson:                   0.429
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10251.058
# Skew:                           0.634   Prob(JB):                         0.00
# Kurtosis:                       2.603   Cond. No.                         380.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:           hrv_residual   R-squared:                        0.5549
# Estimator:                   PanelOLS   R-squared (Between):             -8.7381
# No. Observations:              139225   R-squared (Within):               0.5549
# Date:                Wed, Apr 20 2022   R-squared (Overall):             -0.6850
# Time:                        01:09:03   Log-likelihood                -5.585e+05
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                   8.645e+04
# Entities:                         519   P-value                           0.0000
# Avg Obs:                       268.26   Distribution:                F(2,138704)
# Min Obs:                       6.0000
# Max Obs:                       336.00   F-statistic (robust):          8.645e+04
#                                         P-value                           0.0000
# Time periods:                     336   Distribution:                F(2,138704)
# Avg Obs:                       414.36
# Min Obs:                       385.00
# Max Obs:                       441.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# after_vaccination     0.3362     0.1017     3.3061     0.0009      0.1369      0.5355
# hrv_offset_1          0.7356     0.0018     415.25     0.0000      0.7321      0.7391
# =====================================================================================
#
# F-test for Poolability: 12.021
# P-value: 0.0000
# Distribution: F(518,138704)
#
# Included effects: Entity
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   x = pd.concat(x[::order], 1)
# /opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:2575: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# Effects                     7.692326
# Residual                  179.284765
# Percent due to Effects      0.041140
# Name: Variance Decomposition, dtype: float64
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:           hrv_residual   R-squared:                        0.5574
# Estimator:              RandomEffects   R-squared (Between):              0.8200
# No. Observations:              139225   R-squared (Within):               0.5549
# Date:                Wed, Apr 20 2022   R-squared (Overall):              0.5826
# Time:                        01:09:04   Log-likelihood                -5.588e+05
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                   8.767e+04
# Entities:                         519   P-value                           0.0000
# Avg Obs:                       268.26   Distribution:                F(2,139222)
# Min Obs:                       6.0000
# Max Obs:                       336.00   F-statistic (robust):          8.767e+04
#                                         P-value                           0.0000
# Time periods:                     336   Distribution:                F(2,139222)
# Avg Obs:                       414.36
# Min Obs:                       385.00
# Max Obs:                       441.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# const                -23.898     0.1411    -169.42     0.0000     -24.175     -23.622
# hrv_offset_1          0.7370     0.0018     418.20     0.0000      0.7335      0.7404
# after_vaccination     0.3261     0.1016     3.2104     0.0013      0.1270      0.5252
# =====================================================================================
# None
# (<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f4214cca490>,
#  PanelOLS
#  Num exog: 2, Constant: False
#  Entity Effects: True, Time Effects: False, Num Other Effects: 0
#  id: 0x7f4214dbb0a0,
#  RandomEffects
#  Num exog: 3, Constant: True
#  id: 0x7f4214ea1a00)
